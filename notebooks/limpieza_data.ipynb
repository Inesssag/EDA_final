# %% [markdown]
# # LIMPIEZA DEL DATASET

# %% [markdown]
# Como la data está bastante limpia, lo único que haré será cambiar las tres ciudades que aparecen por tres españolas.
# Además, incluiré dos datasets con las ventas de 'Bolso Viva' así como de los datos de sus clientes.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Supermarket

# %%
# guarda en variables los datasets y su fuente
df_1 = pd.read_csv(r'C:\Users\34690\Documents\THE BRIDGE\Repositorio\Repositorio_cambios_COPIA\2-Data_Analysis\Entregas\EDA_final\data\supermarket_sales - Sheet1.csv')
fuente_1 = "https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales/data"

# %%
#Ver la información de la data
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# Como no hay valores Null, los cambios a realizar serán para adecuar el Dataset al caso en cuestión.
# Los valores de 'City' se cambian por ciudades españolas.

# %%
# Definir el diccionario de ciudades para realizar los cambios
cambio_ciudades = {'Naypyitaw': 'Madrid', 'Yangon': 'Santander', 'Mandalay': 'Valladolid'}

# Cambiar los valores en la columna 'City' utilizando el método replace()
df_1['City'] = df_1['City'].replace(cambio_ciudades)

# Imprimir el DataFrame para verificar los cambios
df_1
# Out:
#       Invoice ID Branch        City Customer type  Gender  \
# 0    750-67-8428      A   Santander        Member  Female
# 1    226-31-3081      C      Madrid        Normal  Female
# 2    631-41-3108      A   Santander        Normal    Male
# 3    123-19-1176      A   Santander        Member    Male
# 4    373-73-7910      A   Santander        Normal    Male
# ..           ...    ...         ...           ...     ...
# 995  233-67-5758      C      Madrid        Normal    Male
# 996  303-96-2227      B  Valladolid        Normal  Female
# 997  727-02-1313      A   Santander        Member    Male
# 998  347-56-2442      A   Santander        Normal    Male
# 999  849-09-3807      A   Santander        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## Ventas y Clientes

# %% [markdown]
# Introducir los otros dos datasets:

# %%
df_2 = pd.read_excel(r'C:\Users\34690\Documents\THE BRIDGE\Repositorio\Repositorio_cambios_COPIA\2-Data_Analysis\Entregas\EDA_final\data\Libro2_limpia_ventas_online.xlsx', index_col=1)

df_2
# Out:
#            PedidoID  Mes   Año    Nombre Producto  Cantidad  Precio  Ingresos  \
# ClienteID
# 101               1    1  2023      Bolso Clasico         2      50       100
# 102               2    1  2023      Bolso Vintage         1      70        70
# 103               3    1  2023     Bolso Elegante         3      60       180
# 104               4    2  2023         Bolso Boho         1      55        55
# 105               5    2  2023       Bolso Casual         2      45        90
# 106               6    2  2023         Bolso Chic         1      75        75
# 107               7    3  2023       Bolso Floral         2      65       130
# 108               8    3  2023        Bolso Playa         1      40        40
# 109               9    3  2023    Bolso Deportivo         3      55       165
# 110              10    4  2023       Bolso Urbano         1      60        60
# 112              11    8  2023  Bolso Minimalista         2      50       100
# ...

# %%
df_3 = pd.read_excel(r'C:\Users\34690\Documents\THE BRIDGE\Repositorio\Repositorio_cambios_COPIA\2-Data_Analysis\Entregas\EDA_final\data\Libro1_limpia_clientes.xlsx', index_col=1)
df_3
# Out:
#         ClienteID   Apellido Fecha de Nacimiento  Genero   Localidad
# Nombre
# Maria         101     Garcia          1985-07-15   Mujer      Madrid
# Laura         102      Lopez          1990-05-23   Mujer  Valladolid
# Elena         103   Martinez          1988-11-10   Mujer    Valencia
# David         104  Rodriguez          1980-03-05  Hombre     Sevilla
# Andrea        105  Fernandez          1992-09-20   Mujer      Bilbao
# Marta         106      Perez          1995-04-28   Mujer      Malaga
# Sara          107    Sanchez          1983-12-07   Mujer    Zaragoza
# Javier        108      Gomez          1987-08-18  Hombre     Granada
# Paula         109       Diaz          1993-01-30   Mujer      Murcia
# Laura         110       Ruiz          1989-06-12   Mujer    Alicante
# Daniel        111   Gonzalez          1984-09-03  Hombre     Cordoba
# Ana           112  Hernandez          1991-02-20   Mujer  Valladolid
# ...
